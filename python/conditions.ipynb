# %%
if(7.001==7.0010):
    print('Same')
else:
    print('Not Same')
# Out:
# Same

# %%
if(7.00==7):
    print('Same')
else:
    print('Not Same')
# Out:
# Same

# %%
list1=set([1,2,3])
list2=set([1,2,3])
if(list1 is list2):
    print('Same')
else:
    print('Not Same')
# Out:
# Not Same

# %%
list1=set([1,2,3])
list2=set([1,2,3])
if(list1 == list2):
    print('Same')
else:
    print('Not Same')
# Out:
# Same

# %%
list3=[1,2,3,4,5]
list4=[1,2,3,4]
if(list3 == list4):
    print('Same')
else:
    print('Not Same')
# Out:
# Not Same

# %%
list5=['banana']
list6=["banana",]
if(list5 == list6):
    print('Same')
else:
    print('Not Same')
# Out:
# Same

# %%
check1=1123
check2=3321
if(check1>3000 and check2>3000):
    print('Both')
elif(check1>3000 or check2>3000):
    print('Either')
else:
    print('None')
# Out:
# Either
# <>:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /var/folders/c2/qxbnyybn2fq7hnt0dbrpjwth0000gn/T/ipykernel_62644/2435170317.py:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if(check1>3000 is check2>3000):

# %%
check3=True
check4=True
check5=False
if(check1>3000):
    if(check3 is not check4):
        print('same')
    elif(check5 is not check4):
        print('Not same')
elif(check2>3000):
    if(check3 is check4):
        print('same')
    elif(check5 is not check4):
        print('Not same')
# Out:
# same
