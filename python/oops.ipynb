# %%
from oops.vehicle import vehicle as v

# %%
TataHarrier=v('Tata','Harrier',4,'Medium',False,1500)

# %%
print(TataHarrier)
# Out:
# Harrier belongs to Tata and has an engine capicity of 1500cc with 4 wheels.
