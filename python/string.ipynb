# %%
a='hello_divyam'
b='_to_the_world'
c=a+b
d=f'{c}' 
print("a: ",a)
print("b: ",b)
print("c: ",c)
print("d: ",d)
# Out:
# a:  hello_divyam
# b:  _to_the_world
# c:  hello_divyam_to_the_world
# d:  hello_divyam_to_the_world

# %%
store_c_1=c[1]
store_c_2=c[1:9]
store_c_3=c[1:9:2]
print(store_c_1)
print(store_c_2)
print(store_c_3)
# Out:
# e
# ello_div
# el_i

# %%
store_c_4=c[len(c):0]
store_c_5=c[len(c):0:-1]
store_c_6=c[len(c):0:-2]
print(store_c_4)
print(store_c_5)
print(store_c_6)
# Out:
# dlrow_eht_ot_mayvid_olleh
# drweto_avdol

# %%
s
