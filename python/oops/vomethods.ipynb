# %%
from vehicleObjects import TataHarrier as th, SuzukiAlto as sz, SuzukiBaleno as sb, SuzukiBrezza as sbr , MahindraXUV7X0 as mxuv
# Out:
# Vehicle_no. =1
# Harrier belongs to Tata and has an engine capicity of 1500cc with 4 wheels.
# Vehicle_no. =2
# Alto belongs to Suzuki and has an engine capicity of 800cc with 4 wheels.

# %%
import pyttsx3 as tts

# %%
engine=tts.init()

# %%
engine.say('hello')

# %%
tts.speak('hello')

# %%
voices=engine.getProperty('voices')
# i=0
# for v in voices:
#     print(f'{i}: {v}')
#     i+=1
# i=0
engine.setProperty('voice', voices[4].id)

# %%
engine.say('hii')
engine.runAndWait()

# %%
tts.speak('hii')
