# %%
from humans import Human as h

# %%
h1=h.create_object()
h2=h.create_object()
h3=h.create_object()
# Out:
# Initialising class.
# Object Created.
# Initialising class.
# Object Created.
# Initialising class.
# Object Created.

# %%
print(f'{h1}\n{h2}\n{h3}')
# Out:
# 7 : Divyam
# 8 : Yash
# 9 : Mayank

# %%
h4=h.create_object()
# Out:
# Initialising class.
# Object Created.

# %%
print(h4)
# Out:
# 11 : huash

# %%
del h4
