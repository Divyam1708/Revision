# %%
from pathlib import Path

# %%
p=Path('text_dir/f1.txt')
p
# Out:
# PosixPath('text_dir/f1.txt')

# %%
p=Path.exists('hello')
p
# Out:
# True

# %%
p=Path.is_dir('hello')
p
# Out:
# False

# %%
p=Path.is_file('text_dir/f1.txt')
p
# Out:
# True

# %%
p=Path.iterdir('text_dir')
p
# Out:
# <generator object Path.iterdir.<locals>.<genexpr> at 0x10a017880>
