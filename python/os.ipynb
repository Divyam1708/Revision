# %%
import os

# %%
os.makedirs('text_dir',exist_ok=True)

# %%
f=open('text_dir/f1.txt','x');

# %%
os.getcwd()
# Out:
# '/Users/divyamkhanna/Documents/Revision/python'

# %%
f=open('text_dir/f1.txt','r')

# %%
for c in f:
    print(c)

# %%
with open('text_dir/f1.txt','w') as wf:
    wf.write('It is a test file.')

# %%
with open('text_dir/f1.txt','r') as rf:
    rf.read()

# %%
f=open('text_dir/f1.txt','r')
f.read()
# Out:
# 'It is a test file.'

# %%
f=open('text_dir/f1.txt','w')
f.write("new TEXT.")
# Out:
# 9

# %%
f=open('text_dir/f1.txt','a')
f.write('\nAppend text')
# Out:
# 12

# %%
f=open('text_dir/f1.txt','r')
f.readlines()
# Out:
# ['new TEXT.\n',
#  'Append text\n',
#  'Append text\n',
#  'Append text\n',
#  'Append text\n',
#  'Append text\n',
#  'Append text\n',
#  'Append text\n',
#  'Append text']

# %%
os.mkdir('hello')

# %%
class B(Exception):
    pass

class C(B):
    pass

class D(C):
    pass

for cls in [B, C, D]:
    try:
        raise cls()
    except D:
        print("D")
    except C:
        print("C")
    except B:
        print("B")
# Out:
# B
# C
# D

# %%
import time
os.mkdir('dir1')
os.rmdir('dir1')
os.makedirs('a/b/c/d/e/f')
time.sleep(3)
os.removedirs('a/b/c/d/e/f')

# %%
# Out:
# <module 'sys' (built-in)>

# %%
os.getcwd()
os.walk('test.txt')
# Out:
# <generator object walk at 0x108867b30>

# %%
os.environ
# Out:
# environ{'COLORTERM': 'truecolor',
#         'COMMAND_MODE': 'unix2003',
#         'ELECTRON_NO_ATTACH_CONSOLE': '1',
#         'HOME': '/Users/divyamkhanna',
#         'HOMEBREW_CELLAR': '/opt/homebrew/Cellar',
#         'HOMEBREW_PREFIX': '/opt/homebrew',
#         'HOMEBREW_REPOSITORY': '/opt/homebrew',
#         'INFOPATH': '/opt/homebrew/share/info:',
#         'LANG': 'en_IN.UTF-8',
#         'LOGNAME': 'divyamkhanna',
#         'LaunchInstanceID': '5DC261C9-9CC0-4385-B93B-046DE95F44EE',
#         'MallocNanoZone': '0',
#         'ORIGINAL_XDG_CURRENT_DESKTOP': 'undefined',
#         'OSLogRateLimit': '64',
# ...
